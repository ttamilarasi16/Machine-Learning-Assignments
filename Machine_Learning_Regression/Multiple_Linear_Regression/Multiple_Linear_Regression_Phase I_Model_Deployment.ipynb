# %%
import pickle

# %%
Loaded_Model = pickle.load(open("finalized_model_MLR.sav",'rb'))

# %%
Result = Loaded_Model.predict([[86789, 456000,765400,0,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Result
# Out:
# array([[148548.62535653]])
