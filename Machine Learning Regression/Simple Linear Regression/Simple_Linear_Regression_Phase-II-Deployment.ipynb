# %%
import pickle #importing pickle
Loaded_Model = pickle.load(open("Finalized_model_SLR.sav",'rb')) #loading the saved model, rb is used to read
user_input = int(input("Enter the years of experience")) #getting user input
Result = Loaded_Model.predict([[user_input]]) #predicting the result for user input value
print("Predicted Salary:", Result) #printing the result
# Out:
# Enter the years of experience 2
# Predicted Salary: [[45497.91391358]]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
