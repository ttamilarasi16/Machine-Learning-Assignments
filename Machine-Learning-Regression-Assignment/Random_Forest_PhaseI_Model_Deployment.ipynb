# %%
import pickle
Loaded_Model = pickle.load(open("Finalized_model_SLR.sav",'rb')) 
Result = Loaded_Model.predict([["28","29","1","0","0"]])
print("Predicted charges:", Result)
# Out:
# Predicted charges: [6071.9613288]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
